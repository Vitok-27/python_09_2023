# %% [markdown]
# <a href="https://colab.research.google.com/github/Vitok-27/python_09_2023/blob/main/Razzorenov.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_style('darkgrid')

# %%
df=pd.read_csv("/content/spotify-2023_fixed.csv")
df.head(10)
# Out:
#                             track_name              artist(s)_name  \
# 0  Seven (feat. Latto) (Explicit Ver.)            Latto, Jung Kook
# 1                                 LALA                 Myke Towers
# 2                              vampire              Olivia Rodrigo
# 3                         Cruel Summer                Taylor Swift
# 4                       WHERE SHE GOES                   Bad Bunny
# 5                             Sprinter           Dave, Central Cee
# 6                      Ella Baila Sola  Eslabon Armado, Peso Pluma
# 7                             Columbia                     Quevedo
# 8                             fukumean                       Gunna
# 9                      La Bebe - Remix       Peso Pluma, Yng Lvcas
#
#    artist_count  released_year  released_month  released_day  \
# 0             2           2023               7            14
# 1             1           2023               3            23
# ...

# %% [markdown]
# # **Работа с данными из таблицы**

# %%
df.nunique().sort_values(ascending=False)
# Out:
# streams                 949
# track_name              943
# in_spotify_playlists    879
# artist(s)_name          645
# in_deezer_playlists     348
# in_apple_playlists      234
# in_shazam_charts        198
# in_apple_charts         172
# bpm                     124
# acousticness_%           98
# valence_%                94
# in_spotify_charts        82
# energy_%                 80
# danceability_%           72
# liveness_%               68
# released_year            50
# speechiness_%            48
# instrumentalness_%       39
# in_deezer_charts         34
# released_day             31
# released_month           12
# key                      11
# artist_count              8
# mode                      2
# dtype: int64

# %%
df.isna().sum()
# Out:
# track_name               0
# artist(s)_name           0
# artist_count             0
# released_year            0
# released_month           0
# released_day             0
# in_spotify_playlists     0
# in_spotify_charts        0
# streams                  0
# in_apple_playlists       0
# in_apple_charts          0
# in_deezer_playlists      0
# in_deezer_charts         0
# in_shazam_charts        50
# bpm                      0
# key                     95
# mode                     0
# danceability_%           0
# valence_%                0
# energy_%                 0
# acousticness_%           0
# instrumentalness_%       0
# liveness_%               0
# speechiness_%            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
# ...

# %%
df.shape
# Out:
# (953, 24)

# %%
df.columns
# Out:
# Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
#        'key', 'mode', 'danceability_%', 'valence_%', 'energy_%',
#        'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%'],
#       dtype='object')

# %%
df.describe()
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    953.000000     953.000000      953.000000    953.000000
# mean       1.556139    2018.238195        6.033578     13.930745
# std        0.893044      11.116218        3.566435      9.201949
# min        1.000000    1930.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts  in_apple_playlists  \
# count            953.000000         953.000000          953.000000
# mean            5200.124869          12.009444           67.812172
# std             7897.608990          19.575992           86.441493
# min               31.000000           0.000000            0.000000
# ...

# %% [markdown]
# # **Tоп пять самых популярных артистов**

# %%
top_five_artists= df.groupby("artist(s)_name").count().sort_values(
    by="track_name", ascending=False)["track_name"][:5]
top_five_artists
# Out:
# artist(s)_name
# Taylor Swift    34
# The Weeknd      22
# SZA             19
# Bad Bunny       19
# Harry Styles    17
# Name: track_name, dtype: int64

# %%
title_dict = {'fontsize': 24, 'fontweight': 'bold', 'color': 'black',
              'family': 'sans-serif'}
lable_dict = {'fontsize': 20, 'color': 'red', 'family': 'sans-serif'}

# %%
plt.figure(figsize=(10, 5))
top_five_artists.plot.barh()
plt.title("Топ пять самых популярных артистов", fontdict=title_dict)
plt.ylabel("Имя артиста", fontdict=lable_dict)
plt.show()

# %% [markdown]
# # **Вывод:**
# ## *На графике представленны топ пять самых популярных артистов начиная с 1930 по  2023.*

# %% [markdown]
# # **Топ пять самых танцевальных трека**

# %%
top_five_danceability=df[["track_name","danceability_%"]].sort_values(by="danceability_%",ascending=False)[:5]
top_five_danceability
# Out:
#               track_name  danceability_%
# 595                 Peru              96
# 224              Players              95
# 250  The Real Slim Shady              95
# 423    Super Freaky Girl              95
# 702            Starlight              95

# %%
title_dict = {'fontsize': 24, 'fontweight': 'bold', 'color': 'black',
              'family': 'sans-serif'}
lable_dict = {'fontsize': 20, 'color': 'red', 'family': 'sans-serif'}
sns.set(rc={'figure.figsize': (10, 5)})
sns.barplot(x="danceability_%", y="track_name", data=top_five_danceability,
            palette="colorblind", alpha=0.3)
plt.title("Топ пять самых танцевальных трека", fontdict=title_dict)
plt.xlabel("danceability_%", fontdict=lable_dict)
plt.ylabel("Название трека", fontdict=lable_dict)
plt.show()

# %% [markdown]
# # **Вывод:**
# ## *На графике представленны топ пять самых тонцевальных треков начиная с 1930 по  2023.*

# %% [markdown]
# # **Артист с самой танцевальной песней**

# %%
top_five_artists_danceability=df[["danceability_%",
                                  "track_name","artist(s)_name"]
                                 ].sort_values(by="danceability_%",
                                               ascending=False)[:10]
top_five_artists_danceability
# Out:
#      danceability_%                   track_name  \
# 595              96                         Peru
# 224              95                      Players
# 250              95          The Real Slim Shady
# 423              95            Super Freaky Girl
# 702              95                    Starlight
# 321              95                        CAIRO
# 876              95                     Ai Preto
# 268              94                  Slut Me Out
# 943              93           Privileged Rappers
# 142              93  Gol Bolinha, Gol Quadrado 2
#
#                              artist(s)_name
# 595                 Ed Sheeran, Fireboy DML
# 224                               Coi Leray
# 250                                  Eminem
# 423                             Nicki Minaj
# 702                                    Dave
# 321               Karol G, Ovy On The Drums
# 876  L7nnon, DJ Biel do Furduncinho, Bianca
# 268                              NLE Choppa
# ...

# %%
plt.figure(figsize=(12,7))
sns.barplot(x="danceability_%",
            y="artist(s)_name",
            data=top_five_artists_danceability)
plt.title("Артист с самой танцевальной песней",
          fontdict=title_dict)
plt.show()

# %%
title_dict = {'fontsize': 24,
              'fontweight': 'bold',
              'color': 'Red',
              'family': 'sans-serif'}
plt.figure(figsize=(12,7))
plt.pie(x="danceability_%",
        data=top_five_artists_danceability,
        autopct="%1.1f%%",
        labels=top_five_artists_danceability.track_name)
plt.title("Самая танцевальная песня",fontdict=title_dict)
plt.show()

# %% [markdown]
# # **Вывод:**
# ### Артист с самым танцевальным треком c 1930 - 2023 стал *Ed Sheeren* с композицией *Peru*
